# %% [markdown]
# <a href="https://colab.research.google.com/github/varun200418/varun200418/blob/main/D_Varun_Kumar_Reddy(RA2211028020033)_3CC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problems Related to Pandas and its operations

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35],
        'City': ['New York', 'Los Angeles', 'Chicago']}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
import pandas as pd

s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
df.head(2)
# Out:
#     Name  Age         City
# 0  Alice   25     New York
# 1    Bob   30  Los Angeles

# %%
df.tail(2)
# Out:
#       Name  Age         City
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df.describe()
# Out:
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.shape
# Out:
# (3, 3)

# %%
df['Age']
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
df[['Name', 'City']]
# Out:
#       Name         City
# 0    Alice     New York
# 1      Bob  Los Angeles
# 2  Charlie      Chicago

# %%
df.loc[1, 'Name']
# Out:
# 'Bob'

# %%
df[df['City'].isin(['New York', 'Chicago'])]
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 2  Charlie   35   Chicago

# %%
df.query('Age > 28')
# Out:
#       Name  Age         City
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df['Salary'] = [50000, 60000, 70000]

# %%
df.insert(1, 'Gender', ['F', 'M', 'M'])

# %%
df.replace('New York', 'NYC')
# Out:
#       Name Gender  Age         City  Salary
# 0    Alice      F   25          NYC   50000
# 1      Bob      M   30  Los Angeles   60000
# 2  Charlie      M   35      Chicago   70000

# %%
df.sort_values(by='Age')
# Out:
#       Name Gender  Age         City  Salary
# 0    Alice      F   25     New York   50000
# 1      Bob      M   30  Los Angeles   60000
# 2  Charlie      M   35      Chicago   70000

# %%
df.sort_values(by=['City', 'Age'], ascending=[True, False])
# Out:
#       Name Gender  Age         City  Salary
# 2  Charlie      M   35      Chicago   70000
# 1      Bob      M   30  Los Angeles   60000
# 0    Alice      F   25     New York   50000

# %%
df.sort_index()
# Out:
#       Name Gender  Age         City  Salary
# 0    Alice      F   25     New York   50000
# 1      Bob      M   30  Los Angeles   60000
# 2  Charlie      M   35      Chicago   70000

# %%
df.groupby('City').sum()
# Out:
#                 Name Gender  Age  Salary
# City
# Chicago      Charlie      M   35   70000
# Los Angeles      Bob      M   30   60000
# New York       Alice      F   25   50000

# %%
df.groupby('City').count()
# Out:
#              Name  Gender  Age  Salary
# City
# Chicago         1       1    1       1
# Los Angeles     1       1    1       1
# New York        1       1    1       1

# %%
df.groupby('City').agg({'Age': 'sum'})
# Out:
#              Age
# City
# Chicago       35
# Los Angeles   30
# New York      25

# %%
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Charlie']})
df2 = pd.DataFrame({'ID': [3, 4, 5], 'Score': [85, 90, 95]})

# %%
pd.concat([df1, df2])
# Out:
#    ID     Name  Score
# 0   1    Alice    NaN
# 1   2      Bob    NaN
# 2   3  Charlie    NaN
# 0   3      NaN   85.0
# 1   4      NaN   90.0
# 2   5      NaN   95.0

# %%
pd.merge(df1, df2, on='ID', how='inner')
# Out:
#    ID     Name  Score
# 0   3  Charlie     85

# %%
df1.join(df2.set_index('ID'), on='ID')
# Out:
#    ID     Name  Score
# 0   1    Alice    NaN
# 1   2      Bob    NaN
# 2   3  Charlie   85.0

# %%
df.isnull()
# Out:
#     Name  Gender    Age   City  Salary
# 0  False   False  False  False   False
# 1  False   False  False  False   False
# 2  False   False  False  False   False

# %%
df.notnull()
# Out:
#    Name  Gender   Age  City  Salary
# 0  True    True  True  True    True
# 1  True    True  True  True    True
# 2  True    True  True  True    True

# %%
df.dropna()
# Out:
#       Name Gender  Age         City  Salary
# 0    Alice      F   25     New York   50000
# 1      Bob      M   30  Los Angeles   60000
# 2  Charlie      M   35      Chicago   70000

# %%
df.fillna(0)
# Out:
#       Name Gender  Age         City  Salary
# 0    Alice      F   25     New York   50000
# 1      Bob      M   30  Los Angeles   60000
# 2  Charlie      M   35      Chicago   70000

# %%
df['Date'] = pd.to_datetime(['2023-01-01', '2023-06-15', '2023-12-31'])

# %%
df['Date'].dt.year
# Out:
# 0    2023
# 1    2023
# 2    2023
# Name: Date, dtype: int32

# %%
df.to_csv('data.csv')

# %%
df.to_excel('data.xlsx')

# %%
df.to_json('data.json')

# %% [markdown]
# Web Scrapping (Problems)

# %%
import requests
from bs4 import BeautifulSoup

url = "https://example.com"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

title = soup.find("h1").text
print(title)
# Out:
# Example Domain

# %%
import requests

url = "https://example.com"
response = requests.get(url)
print(response.status_code)
print(response.text)
# Out:
# 200
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# ...

# %%
from bs4 import BeautifulSoup

html = "<html><body><h1>Hello World</h1></body></html>"
soup = BeautifulSoup(html, "html.parser")
print(soup.h1.text)
# Out:
# Hello World

# %%
import csv

data = [["Title", "Price"], ["Item 1", "$10"]]
with open("data.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(data)

# %%
headers = {"User-Agent": "Mozilla/5.0"}
requests.get("https://example.com", headers=headers)
# Out:
# <Response [200]>

# %%
from flask import Flask, jsonify, request

app = Flask(__name__)

users = [
    {"id": 1, "name": "Alice", "age": 25},
    {"id": 2, "name": "Bob", "age": 30}
]

@app.route("/users", methods=["GET"])
def get_users():
    return jsonify(users)

@app.route("/users/<int:user_id>", methods=["GET"])
def get_user(user_id):
    user = next((u for u in users if u["id"] == user_id), None)
    return jsonify(user) if user else ("User not found", 404)

@app.route("/users", methods=["POST"])
def add_user():
    new_user = request.json
    users.append(new_user)
    return jsonify(new_user), 201

@app.route("/users/<int:user_id>", methods=["PUT"])
def update_user(user_id):
    user = next((u for u in users if u["id"] == user_id), None)
    if user:
        user.update(request.json)
        return jsonify(user)
    return ("User not found", 404)

@app.route("/users/<int:user_id>", methods=["DELETE"])
def delete_user(user_id):
    global users
    users = [u for u in users if u["id"] != user_id]
    return ("", 204)

if __name__ == "__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat
